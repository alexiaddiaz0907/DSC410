# %%
from pandas import read_csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#import data - Auto Insurance Customer Data
data = read_csv("/Users/alexiadiaz/Desktop/AutoInsurance.csv")
#print(data)
data.head
# Out:
# <bound method NDFrame.head of      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
#Columns
data.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
data.shape
# Out:
# (9134, 24)

# %%
#Check the type of each column
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
#Gives the sum of the null values for each column
data.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# Changing Category data to numerical
data['Gender'] = data['Gender'].map({'F': 1, 'M': 0})

# Display modified DataFrame
print(data['Gender'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9129    0
# 9130    1
# 9131    0
# 9132    0
# 9133    0
# Name: Gender, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Coverage'] = data['Coverage'].map({'Premium':1, 'Basic':0,'Extended':2})

# Display modified DataFrame
print(data['Coverage'])
# Out:
# 0       0
# 1       2
# 2       1
# 3       0
# 4       0
#        ..
# 9129    0
# 9130    2
# 9131    2
# 9132    2
# 9133    2
# Name: Coverage, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Education'] = data['Education'].map({'College':1, 'High School or Below':0,'Bachelor': 2, 'Master':3, 'Doctor':4})

# Display modified DataFrame
print(data['Education'])
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 9129    2
# 9130    1
# 9131    2
# 9132    1
# 9133    1
# Name: Education, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Location Code'] = data['Location Code'].map({'Suburban': 1, 'Urban': 0, 'Rural':2})

# Display modified DataFrame
print(data['Location Code'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 9129    0
# 9130    1
# 9131    1
# 9132    1
# 9133    1
# Name: Location Code, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Marital Status'] = data['Marital Status'].map({'Married': 1, 'Single': 0, 'Divorced':2})

# Display modified DataFrame
print(data['Marital Status'])
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 9129    1
# 9130    2
# 9131    0
# 9132    1
# 9133    0
# Name: Marital Status, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Policy Type'] = data['Policy Type'].map({'Corporate Auto': 1, 'Personal Auto': 0, 'Special Auto':2})

# Display modified DataFrame
print(data['Policy Type'])
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 9129    0
# 9130    1
# 9131    1
# 9132    0
# 9133    1
# Name: Policy Type, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Vehicle Size'] = data['Vehicle Size'].map({'Medsize': 1, 'Small': 0, 'Large':2})

# Display modified DataFrame
print(data['Vehicle Size'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9129    1
# 9130    1
# 9131    1
# 9132    2
# 9133    1
# Name: Vehicle Size, Length: 9134, dtype: int64

# %%
# Changing Category data to numerical
data['Vehicle Class'] = data['Vehicle Class'].map({'Four-Door Car': 1, 'Two-Door Car': 0, 'SUV':2, 'Luxury Car':3, 'Luxury SUV':4, 'Sports Car':5})

# Display modified DataFrame
print(data['Vehicle Class'])
# Out:
# 0       0
# 1       1
# 2       0
# 3       2
# 4       1
#        ..
# 9129    1
# 9130    1
# 9131    1
# 9132    1
# 9133    0
# Name: Vehicle Class, Length: 9134, dtype: int64

# %%
data.drop(['Response','Renew Offer Type', 'Sales Channel', 'Effective To Date'],axis=1, inplace=True)
data.head()
# Out:
#   Customer       State  Customer Lifetime Value  Coverage  Education  \
# 0  BU79786  Washington              2763.519279         0          2
# 1  QZ44356     Arizona              6979.535903         2          2
# 2  AI49188      Nevada             12887.431650         1          2
# 3  WW63253  California              7645.861827         0          2
# 4  HB64268  Washington              2813.692575         0          2
#
#   EmploymentStatus  Gender  Income  Location Code  Marital Status  \
# 0         Employed       1   56274              1               1
# 1       Unemployed       1       0              1               0
# 2         Employed       1   48767              1               1
# 3       Unemployed       0       0              1               1
# 4         Employed       0   43836              2               0
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
#Confirm again no null values after changing some columns to numerical
data.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Coverage                         0
# Education                        0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
data[['Customer Lifetime Value', 'Income',
    'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Total Claim Amount']].hist(bins=30,figsize=(20, 20))
plt.show()

# %%
continous_var = data[['Customer Lifetime Value', 'Income','Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Number of Open Complaints', 'Number of Policies', 'Total Claim Amount']]
continous_var.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
#Numerical Values correlation
continous_var.corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.024366
# Income                                        0.024366  1.000000
# Monthly Premium Auto                          0.396262 -0.016665
# Months Since Last Claim                       0.011517 -0.026715
# Months Since Policy Inception                 0.009418 -0.000875
# Number of Open Complaints                    -0.036343  0.006408
# Number of Policies                            0.021955 -0.008656
# Total Claim Amount                            0.226451 -0.355254
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.396262                 0.011517
# Income                                    -0.016665                -0.026715
# Monthly Premium Auto                       1.000000                 0.005026
# ...

# %%
#Plot corrlation matrix for better understanding
plt.figure(figsize=(9,9))
sns.heatmap(continous_var.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
data.corr()
# Out:
# /var/folders/jb/3zqqr7s5653836mlnbgv7z640000gn/T/ipykernel_88151/1667495705.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                Customer Lifetime Value  Coverage  Education  \
# Customer Lifetime Value                       1.000000  0.118071  -0.018772
# Coverage                                      0.118071  1.000000  -0.007872
# Education                                    -0.018772 -0.007872   1.000000
# Gender                                        0.013610  0.017514   0.010496
# Income                                        0.024366 -0.024853   0.067275
# Location Code                                -0.004854  0.007231   0.018900
# Marital Status                                0.026003  0.003103   0.096416
# ...

# %%
#Plot corrlation matrix for better understanding
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True)
# Out:
# /var/folders/jb/3zqqr7s5653836mlnbgv7z640000gn/T/ipykernel_88151/3295835425.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <AxesSubplot: >

# %%
#show corr between two variables
# Noticed Corr between cost of insurance and vehicle class - As the vehicle class becomes larger, more expensive or sporter the monthly premium increases
sns.scatterplot(x="Vehicle Class", y="Monthly Premium Auto", data=data);

# %%
# This plot shows that typically people with low premium cost has low total claim amount. Higher premium cost tends to be seen with higher claim amount.

sns.scatterplot(x="Monthly Premium Auto", y="Total Claim Amount", data=data);

# %%
# This plot shows that as the vehicle class becomes larger or sporter the total claim amount increases

sns.scatterplot(x="Vehicle Class", y="Total Claim Amount", data=data);

# %%
#This plot shows that as the monthly premium increases typically the customer lifetime value increases
sns.scatterplot ( x="Monthly Premium Auto", y="Customer Lifetime Value", data=data );

# %%
    # #1. What types of variables are there in the dataset?
    # #Numerical and category variables
    # #2. What do their distributions look like?
    # #Customer Lifetime Value - Skewed Right
    # Income - Random
    # Monthly Premium Auto - Skewed Right
    # Months Since Last Claim - Skewed Right
    # Months Since Policy Inception - uniform
    # Number of Open Complaints - Skewed Right
    # Number of Policies - Skewed Right
    # Total Claim Amount - Skewed Right
    # 3. Do you have missing values?
    # No
    # 4. Are there redundant features?
    # Yes - I dropped three features that was not needed
    # 5. What are the relationships between the main features?
    # I found a relationship between monthly premium auto and total claim amount, monthly premium auto & Customer Lifetime Value, Coverage and monthly premium auto, Vehicle size and monthly premium, vehicle class and total claim amount
    # 6. Do you observe outliers?
    # Yes there was outliers the following categories: income, monthly premium auto, Months since last claim, months ince policy inception, number of policies and total claim amount
    # 7. How do the different pairs of features correlate with one another?
    # I created four Scatter plots. The first plot shows as the vehicle class becomes larger, more expensive or sporter the monthly premium increases. The Second plot shows as the vehicle class becomes larger or sporter the monthly premium increases. The third plotshows that as the vehicle class becomes larger or sporter the total claim amount increases. The fourth plot shows that as the monthly premium increases typically the customer lifetime value increases.
    # 8. Do these correlations make sense?
    # Yes, I already thought these factors play a role with your premiums. Next I will be changing the states into numerical features to see if that also effects the premium cos.
    # 9. What is the relationship between the features and the target?
    # 10. Have you confirmed or rejected your hypothesis?
    # YesI have confirmed alot of my hypothesis on factors that effect insurance monthly cost.
    # 11. What do you know now that will inform the modeling strategy?
    # That certain changes in a customers services whether adding a new vehicle if different in class & size  to the policy causes higher premiums and the likely hood of more claims.
